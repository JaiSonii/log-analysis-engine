# %%
import os
import sys

# Add the project root directory to Python path
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))

if project_root not in sys.path:
    sys.path.append(project_root)
print(f"Added {project_root} to Python path")
# Out:
# Added c:\Machine Learning\log-analyzer to Python path

# %%
from app.core.rule_converter import RuleConverter

converter = RuleConverter()

# Provide sample logs from YOUR application
sample_logs = """
2025-10-05 14:47:03 | INFO     | Starting recording for game abc123
2025-10-05 14:47:15 | INFO     | Recording stopped for game abc123
"""

rules = converter.invoke(
    file_path="C:\\web development projects\\FOG\\laser-tag\\fog-laser-tag\\src\\moments\\repomix-output.xml",
    sample_logs=sample_logs  # This helps LLM understand your format
)

# Use rules
# from log_chunker import LogChunker
# chunker = LogChunker(rules)
# chunks = chunker.chunk_file('your_app.log')
# Out:
# c:\Machine Learning\log-analyzer\app\core\rule_converter.py:20: SyntaxWarning: invalid escape sequence '\d'
#   SYSTEM_PROMPT = """

# %%
rules
# Out:
# [Rule(rule_name='General Error', priority=1, type='Multi-line Error', start_pattern='^.*(ERROR|Exception|Traceback).*', end_pattern='^(\\d{4}-\\d{2}-\\d{2}.*|$)'),
#  Rule(rule_name='Application Update Process', priority=2, type='Transaction', start_pattern='^.*Updating\\s+app\\s+to\\s+version\\s+([0-9.]+)\\s+from\\s+pre-signed\\s+URL', end_pattern='^.*Version\\s+([0-9.]+)\\s+is\\s+ready\\s+for\\s+the\\s+next\\s+launch'),
#  Rule(rule_name='Application Launch Process', priority=2, type='Transaction', start_pattern='^.*Attempting\\s+to\\s+launch:\\s+.*app\\.exe', end_pattern='^.*Successfully\\s+launched\\s+version\\s+([0-9.]+)\\.'),
#  Rule(rule_name='Recording Session', priority=2, type='Transaction', start_pattern='^.*Starting\\s+recording\\s+for\\s+game\\s+([a-zA-Z0-9-]+)', end_pattern='^.*Recording\\s+stopped\\s+successfully\\s+for\\s+game\\s+([a-zA-Z0-9-]+)'),
#  Rule(rule_name='Cloudflare Token Generation', priority=3, type='Transaction', start_pattern='^.*Creating\\s+token\\s+for\\s+game_id:\\s+([a-zA-Z0-9-]+)', end_pattern='^.*Generated\\s+new\\s+token\\s+([a-zA-Z0-9-]+)\\s+for\\s+file'),
#  Rule(rule_name='Download Session Tracking', priority=3, type='Transaction', start_pattern='^.*"session_id"\\s*:\\s*"([a-zA-Z0-9-]+)".*"event"\\s*:\\s*"new_session_start"', end_pattern='^.*"session_id"\\s*:\\s*"([a-zA-Z0-9-]+)".*"event"\\s*:\\s*"session_ended"'),
#  Rule(rule_name='File Encryption', priority=3, type='Transaction', start_pattern='^.*Starting\\s+encryption\\s+of\\s+(.*)\\s+\\(', end_pattern='^.*Encryption\\s+completed\\s+in\\s+.*\\s+seconds'),
#  Rule(rule_name='File Decryption', priority=3, type='Transaction', start_pattern='^.*Starting\\s+decryption\\s+of\\s+(.*)\\s+\\(', end_pattern='^.*Decryption\\s+completed\\s+in\\s+.*\\s+seconds'),
#  Rule(rule_name='Template Update Process', priority=3, type='Transaction', start_pattern='^.*Updating\\s+template\\s+([a-zA-Z0-9-]+)\\s+from\\s+pre-signed\\s+URL', end_pattern='^.*Template\\s+([a-zA-Z0-9-]+)\\s+update\\s+completed\\s+successfully'),
#  Rule(rule_name='Photo Processing Lifecycle', priority=4, type='Transaction', start_pattern='^.*Photo\\s+Process\\s+is\\s+now\\s+running', end_pattern='^.*completing\\s+photo\\s+process'),
#  Rule(rule_name='Video Analyzer Lifecycle', priority=4, type='Transaction', start_pattern='^.*Analyzer\\s+process\\s+is\\s+running\\s+now', end_pattern='^.*Analyzer\\s+process\\s+completed'),
#  Rule(rule_name='Camera Thread Lifecycle', priority=4, type='Transaction', start_pattern='^.*Camera\\s+([0-9]+)\\s+thread\\s+started', end_pattern='^.*Camera\\s+([0-9]+)\\s+closed'),
#  Rule(rule_name='Video Clip Creation', priority=4, type='Transaction', start_pattern='^.*Recording:\\s+(.*segment_[0-9]+\\.mp4)', end_pattern='^.*Successfully\\s+created\\s+(.*segment_[0-9]+\\.mp4)\\s+of\\s+.*\\s+bytes'),
#  Rule(rule_name='Full Video Concatenation Process', priority=4, type='Transaction', start_pattern='^.*Starting\\s+full\\s+video\\s+concatenation', end_pattern='^.*Full\\s+concatenation\\s+video\\s+created:\\s+(.*)'),
#  Rule(rule_name='Highlight Video Creation Process', priority=4, type='Transaction', start_pattern='^.*Starting\\s+highlight\\s+video\\s+creation', end_pattern='^.*Highlight\\s+video\\s+created:\\s+(.*)'),
#  Rule(rule_name='Concurrent Video Processing Lifecycle', priority=4, type='Transaction', start_pattern='^.*Starting\\s+concurrent\\s+video\\s+processing', end_pattern='^.*Video\\s+processing\\s+completed\\.\\s+Results:\\s+(.*)'),
#  Rule(rule_name='Socket.IO Client Connection Lifecycle', priority=4, type='Transaction', start_pattern='^.*Connecting\\s+to\\s+(.*)\\.\\.\\.', end_pattern='^.*(Connected!|Disconnected!)'),
#  Rule(rule_name='Application Shutdown Process', priority=4, type='Transaction', start_pattern='^.*Singal\\s+Recieved', end_pattern='^.*Received\\s+shutdown\\s+signal,\\s+exiting\\.\\.\\.')]

# %%
from app.core.rule_converter import RuleConverter
import re

sample_logs = """
2025-10-05 14:47:03 | INFO | app.api.recording:start_recording:32 - Starting recording for game 68e236ef72613cc4b4be0905 of type soloDeathMatch
2025-10-05 14:47:04 | ERROR | app.core.camera_manager:can_record:20 - Camera 3 could not be opened.
2025-10-05 14:52:54 | INFO | app.api.recording:stop_recording:65 - Recording stopped successfully for game 68e236ef72613cc4b4be0905
"""

# Test the first few
test_line = "2025-10-05 21:02:36 | INFO | app.core.analyzer_manager:send_frame:30 - Adding clip"
for rule in rules[:3]:
    match = re.search(rule.start_pattern, test_line)
    print(f"{rule.rule_name}: {'✓ MATCH' if match else '✗ no match'}")
# Out:
# General Error: ✗ no match
# Application Update Process: ✗ no match
# Application Launch Process: ✗ no match

# %%
"""
Log Chunker Module - Groups log lines into meaningful chunks based on rules
"""
import re
from typing import List, Optional, Dict, Tuple
from dataclasses import dataclass, field
from enum import Enum
from app.models import Rule


class ChunkStatus(Enum):
    """Status of a chunk"""
    COMPLETE = "complete"
    INCOMPLETE = "incomplete"
    UNMATCHED = "unmatched"


@dataclass
class Chunk:
    """Represents a grouped set of log lines"""
    rule_name: str
    rule_type: str  # 'Transaction' or 'Multi-line Error'
    lines: List[str] = field(default_factory=list)
    status: ChunkStatus = ChunkStatus.INCOMPLETE
    start_line_num: int = 0
    end_line_num: Optional[int] = None
    extracted_ids: Dict[str, str] = field(default_factory=dict)  # e.g., {'game_id': 'ABC123'}
    metadata: Dict = field(default_factory=dict)
    
    def add_line(self, line: str, line_num: int):
        """Add a line to this chunk"""
        self.lines.append(line)
        if not self.start_line_num:
            self.start_line_num = line_num
        self.end_line_num = line_num
    
    def get_text(self) -> str:
        """Get all lines as a single text"""
        return '\n'.join(self.lines)
    
    def mark_complete(self):
        """Mark this chunk as complete"""
        self.status = ChunkStatus.COMPLETE
    
    def to_dict(self) -> dict:
        """Convert chunk to dictionary for serialization"""
        return {
            'rule_name': self.rule_name,
            'rule_type': self.rule_type,
            'status': self.status.value,
            'start_line_num': self.start_line_num,
            'end_line_num': self.end_line_num,
            'line_count': len(self.lines),
            'text': self.get_text(),
            'extracted_ids': self.extracted_ids,
            'metadata': self.metadata
        }


class LogChunker:
    """
    Chunks log files based on provided rules.
    Handles both transactions (with unique IDs) and multi-line errors.
    """
    
    def __init__(
        self, 
        rules: List[Rule],
        log_line_pattern: str = r'^\d{4}-\d{2}-\d{2}\s+\d{2}:\d{2}:\d{2}\s+\|',
        max_incomplete_buffer: int = 10000,
        force_close_after_lines: int = 1000,
        debug: bool = False
    ):
        """
        Initialize the log chunker.
        
        Args:
            rules: List of Rule objects to use for chunking
            log_line_pattern: Regex pattern to identify start of a new log entry
                Default matches: "YYYY-MM-DD HH:MM:SS |" with flexible whitespace
            max_incomplete_buffer: Maximum number of incomplete chunks to track
            force_close_after_lines: Force close incomplete chunks after this many lines
            debug: Enable debug output
        """
        self.rules = sorted(rules, key=lambda r: r.priority)  # Sort by priority
        self.log_line_pattern = re.compile(log_line_pattern)
        self.max_incomplete_buffer = max_incomplete_buffer
        self.force_close_after_lines = force_close_after_lines
        self.debug = debug
        
        # Compile all regex patterns
        for rule in self.rules:
            try:
                rule._start_regex = re.compile(rule.start_pattern)
                rule._end_regex = re.compile(rule.end_pattern)
            except re.error as e:
                print(f"⚠️  Skipping rule '{rule.rule_name}' - invalid pattern: {e}")
                self.rules.remove(rule)
    
    def chunk_file(self, file_path: str) -> List[Chunk]:
        """
        Chunk a log file into meaningful groups.
        
        Args:
            file_path: Path to the log file
            
        Returns:
            List of Chunk objects
        """
        with open(file_path, 'r', encoding='utf-8', errors='replace') as f:
            return self.chunk_lines(f)
    
    def chunk_lines(self, lines) -> List[Chunk]:
        """
        Chunk an iterable of log lines.
        
        Args:
            lines: Iterable of log lines (file object or list)
            
        Returns:
            List of Chunk objects
        """
        completed_chunks: List[Chunk] = []
        active_transactions: Dict[str, Chunk] = {}  # key: rule_name + extracted_ids
        active_multiline: Optional[Chunk] = None
        line_num = 0
        
        for line in lines:
            line_num += 1
            line = line.rstrip('\n')
            
            if self.debug:
                print(f"\n--- Line {line_num}: {line[:80]}...")
                print(f"    Active transactions: {len(active_transactions)}")
                print(f"    Active multiline: {active_multiline is not None}")
            
            # Check if this line is the start of a new log entry
            is_new_entry = bool(self.log_line_pattern.match(line))
            
            # Try to match this line as an END pattern for active transactions
            matched_as_end = False
            if is_new_entry and active_transactions:
                for rule in self.rules:
                    if rule.type != 'Transaction':
                        continue
                    
                    end_match = rule._end_regex.search(line)
                    if end_match:
                        extracted_ids = self._extract_ids(end_match)
                        
                        # Find matching transaction
                        for key, chunk in list(active_transactions.items()):
                            if chunk.rule_name == rule.rule_name and self._ids_match(chunk.extracted_ids, extracted_ids):
                                chunk.add_line(line, line_num)
                                chunk.mark_complete()
                                completed_chunks.append(chunk)
                                del active_transactions[key]
                                matched_as_end = True
                                
                                if self.debug:
                                    print(f"    ✓ Matched END for transaction: {rule.rule_name}")
                                break
                    
                    if matched_as_end:
                        break
            
            if matched_as_end:
                continue
            
            # Try to match this line as a START pattern
            matched_as_start = False
            if is_new_entry:
                for rule in self.rules:
                    start_match = rule._start_regex.search(line)
                    if start_match:
                        if self.debug:
                            print(f"    ✓ Matched START: {rule.rule_name} ({rule.type})")
                        
                        if rule.type == 'Transaction':
                            # Extract IDs and create new transaction
                            extracted_ids = self._extract_ids(start_match)
                            chunk_key = self._make_chunk_key(rule.rule_name, extracted_ids)
                            
                            chunk = Chunk(
                                rule_name=rule.rule_name,
                                rule_type=rule.type,
                                extracted_ids=extracted_ids
                            )
                            chunk.add_line(line, line_num)
                            active_transactions[chunk_key] = chunk
                            matched_as_start = True
                            
                        elif rule.type == 'Multi-line Error':
                            # Close previous multiline error if exists
                            if active_multiline:
                                active_multiline.mark_complete()
                                completed_chunks.append(active_multiline)
                            
                            # Start new multiline error
                            active_multiline = Chunk(
                                rule_name=rule.rule_name,
                                rule_type=rule.type
                            )
                            active_multiline.add_line(line, line_num)
                            matched_as_start = True
                        
                        break  # First matching rule wins (priority-based)
                    elif self.debug and line_num <= 5:
                        # Show why first few lines don't match (for debugging)
                        print(f"    ✗ No match: {rule.rule_name}")
            
            if matched_as_start:
                continue
            
            # If not matched as start/end, check if it's a continuation line for multiline error
            if active_multiline and not is_new_entry:
                active_multiline.add_line(line, line_num)
                if self.debug:
                    print(f"    → Added to active multiline error")
                continue
            
            # Check if multiline error should end (new log entry that doesn't start a new pattern)
            if active_multiline and is_new_entry:
                # Check if this line matches the end pattern
                for rule in self.rules:
                    if rule.type == 'Multi-line Error' and active_multiline.rule_name == rule.rule_name:
                        if rule._end_regex.match(line):
                            active_multiline.mark_complete()
                            completed_chunks.append(active_multiline)
                            active_multiline = None
                            if self.debug:
                                print(f"    ✓ Closed multiline error (end pattern matched)")
                            break
            
            # If we have a new entry that didn't match any START pattern, it's unmatched
            if is_new_entry and not matched_as_start:
                unmatched_chunk = Chunk(
                    rule_name="Unmatched",
                    rule_type="Single Line",
                    status=ChunkStatus.UNMATCHED
                )
                unmatched_chunk.add_line(line, line_num)
                completed_chunks.append(unmatched_chunk)
                
                if self.debug:
                    print(f"    → Created unmatched chunk")
            
            # Force close old incomplete transactions
            self._force_close_old_chunks(active_transactions, completed_chunks, line_num)
            
            # Limit buffer size
            if len(active_transactions) > self.max_incomplete_buffer:
                self._flush_oldest_chunks(active_transactions, completed_chunks)
        
        # Close remaining incomplete chunks
        if active_multiline:
            completed_chunks.append(active_multiline)
        
        for chunk in active_transactions.values():
            completed_chunks.append(chunk)
        
        return completed_chunks
    
    def _make_chunk_key(self, rule_name: str, extracted_ids: Dict[str, str]) -> str:
        """Create unique key for a transaction chunk"""
        id_str = '_'.join(f"{k}={v}" for k, v in sorted(extracted_ids.items()))
        return f"{rule_name}::{id_str}" if id_str else f"{rule_name}::no_id"
    
    def _extract_ids(self, match) -> Dict[str, str]:
        """Extract captured groups from regex match as IDs"""
        ids = {}
        for i, group in enumerate(match.groups()):
            if group:
                ids[f'id_{i}'] = group
        return ids
    
    def _ids_match(self, ids1: Dict[str, str], ids2: Dict[str, str]) -> bool:
        """Check if extracted IDs match (for pairing start/end of transactions)"""
        if not ids1 or not ids2:
            return True  # If no IDs extracted, consider it a match
        
        # Check if any common keys have matching values
        common_keys = set(ids1.keys()) & set(ids2.keys())
        if not common_keys:
            return True
        
        return any(ids1[key] == ids2[key] for key in common_keys)
    
    def _force_close_old_chunks(
        self, 
        active_transactions: Dict[str, Chunk], 
        completed_chunks: List[Chunk],
        current_line: int
    ):
        """Force close chunks that have been open too long"""
        to_remove = []
        for key, chunk in active_transactions.items():
            if current_line - chunk.start_line_num > self.force_close_after_lines:
                chunk.metadata['forced_close'] = True
                completed_chunks.append(chunk)
                to_remove.append(key)
        
        for key in to_remove:
            del active_transactions[key]
    
    def _flush_oldest_chunks(
        self,
        active_transactions: Dict[str, Chunk],
        completed_chunks: List[Chunk]
    ):
        """Flush oldest chunks when buffer is full"""
        # Sort by start line and close oldest 10%
        sorted_chunks = sorted(active_transactions.items(), key=lambda x: x[1].start_line_num)
        num_to_flush = max(1, len(sorted_chunks) // 10)
        
        for i in range(num_to_flush):
            key, chunk = sorted_chunks[i]
            chunk.metadata['buffer_flush'] = True
            completed_chunks.append(chunk)
            del active_transactions[key]

# %%
rules
# Out:
# [Rule(rule_name='General Error', priority=1, type='Multi-line Error', start_pattern='^.*(ERROR|Exception|Traceback).*', end_pattern='^(\\d{4}-\\d{2}-\\d{2}.*|$)'),
#  Rule(rule_name='Application Update Process', priority=2, type='Transaction', start_pattern='^.*Updating\\s+app\\s+to\\s+version\\s+([0-9.]+)\\s+from\\s+pre-signed\\s+URL', end_pattern='^.*Version\\s+([0-9.]+)\\s+is\\s+ready\\s+for\\s+the\\s+next\\s+launch'),
#  Rule(rule_name='Application Launch Process', priority=2, type='Transaction', start_pattern='^.*Attempting\\s+to\\s+launch:\\s+.*app\\.exe', end_pattern='^.*Successfully\\s+launched\\s+version\\s+([0-9.]+)\\.'),
#  Rule(rule_name='Recording Session', priority=2, type='Transaction', start_pattern='^.*Starting\\s+recording\\s+for\\s+game\\s+([a-zA-Z0-9-]+)', end_pattern='^.*Recording\\s+stopped\\s+successfully\\s+for\\s+game\\s+([a-zA-Z0-9-]+)'),
#  Rule(rule_name='Cloudflare Token Generation', priority=3, type='Transaction', start_pattern='^.*Creating\\s+token\\s+for\\s+game_id:\\s+([a-zA-Z0-9-]+)', end_pattern='^.*Generated\\s+new\\s+token\\s+([a-zA-Z0-9-]+)\\s+for\\s+file'),
#  Rule(rule_name='Download Session Tracking', priority=3, type='Transaction', start_pattern='^.*"session_id"\\s*:\\s*"([a-zA-Z0-9-]+)".*"event"\\s*:\\s*"new_session_start"', end_pattern='^.*"session_id"\\s*:\\s*"([a-zA-Z0-9-]+)".*"event"\\s*:\\s*"session_ended"'),
#  Rule(rule_name='File Encryption', priority=3, type='Transaction', start_pattern='^.*Starting\\s+encryption\\s+of\\s+(.*)\\s+\\(', end_pattern='^.*Encryption\\s+completed\\s+in\\s+.*\\s+seconds'),
#  Rule(rule_name='File Decryption', priority=3, type='Transaction', start_pattern='^.*Starting\\s+decryption\\s+of\\s+(.*)\\s+\\(', end_pattern='^.*Decryption\\s+completed\\s+in\\s+.*\\s+seconds'),
#  Rule(rule_name='Template Update Process', priority=3, type='Transaction', start_pattern='^.*Updating\\s+template\\s+([a-zA-Z0-9-]+)\\s+from\\s+pre-signed\\s+URL', end_pattern='^.*Template\\s+([a-zA-Z0-9-]+)\\s+update\\s+completed\\s+successfully'),
#  Rule(rule_name='Photo Processing Lifecycle', priority=4, type='Transaction', start_pattern='^.*Photo\\s+Process\\s+is\\s+now\\s+running', end_pattern='^.*completing\\s+photo\\s+process'),
#  Rule(rule_name='Video Analyzer Lifecycle', priority=4, type='Transaction', start_pattern='^.*Analyzer\\s+process\\s+is\\s+running\\s+now', end_pattern='^.*Analyzer\\s+process\\s+completed'),
#  Rule(rule_name='Camera Thread Lifecycle', priority=4, type='Transaction', start_pattern='^.*Camera\\s+([0-9]+)\\s+thread\\s+started', end_pattern='^.*Camera\\s+([0-9]+)\\s+closed'),
#  Rule(rule_name='Video Clip Creation', priority=4, type='Transaction', start_pattern='^.*Recording:\\s+(.*segment_[0-9]+\\.mp4)', end_pattern='^.*Successfully\\s+created\\s+(.*segment_[0-9]+\\.mp4)\\s+of\\s+.*\\s+bytes'),
#  Rule(rule_name='Full Video Concatenation Process', priority=4, type='Transaction', start_pattern='^.*Starting\\s+full\\s+video\\s+concatenation', end_pattern='^.*Full\\s+concatenation\\s+video\\s+created:\\s+(.*)'),
#  Rule(rule_name='Highlight Video Creation Process', priority=4, type='Transaction', start_pattern='^.*Starting\\s+highlight\\s+video\\s+creation', end_pattern='^.*Highlight\\s+video\\s+created:\\s+(.*)'),
#  Rule(rule_name='Concurrent Video Processing Lifecycle', priority=4, type='Transaction', start_pattern='^.*Starting\\s+concurrent\\s+video\\s+processing', end_pattern='^.*Video\\s+processing\\s+completed\\.\\s+Results:\\s+(.*)'),
#  Rule(rule_name='Socket.IO Client Connection Lifecycle', priority=4, type='Transaction', start_pattern='^.*Connecting\\s+to\\s+(.*)\\.\\.\\.', end_pattern='^.*(Connected!|Disconnected!)'),
#  Rule(rule_name='Application Shutdown Process', priority=4, type='Transaction', start_pattern='^.*Singal\\s+Recieved', end_pattern='^.*Received\\s+shutdown\\s+signal,\\s+exiting\\.\\.\\.')]

# %%
chunker = LogChunker(rules, debug=True)
chunks = chunker.chunk_file('C:\\Machine Learning\\log-analyzer\\data\\python.log')
# Out:
# --- Line 1: 2025-10-05 11:06:21 | INFO     | app.core.configurations:ensure_config_directory...
#     Active transactions: 0
#     Active multiline: False
#     ✗ No match: General Error
#     ✗ No match: Application Update Process
#     ✗ No match: Application Launch Process
#     ✗ No match: Recording Session
#     ✗ No match: Cloudflare Token Generation
#     ✗ No match: Download Session Tracking
#     ✗ No match: File Encryption
#     ✗ No match: File Decryption
#     ✗ No match: Template Update Process
#     ✗ No match: Photo Processing Lifecycle
#     ✗ No match: Video Analyzer Lifecycle
#     ✗ No match: Camera Thread Lifecycle
#     ✗ No match: Video Clip Creation
#     ✗ No match: Full Video Concatenation Process
#     ✗ No match: Highlight Video Creation Process
#     ✗ No match: Concurrent Video Processing Lifecycle
#     ✗ No match: Socket.IO Client Connection Lifecycle
#     ✗ No match: Application Shutdown Process
#     → Created unmatched chunk
#
# --- Line 2: 2025-10-05 11:06:21 | INFO     | app.core.configurations:ensure_config_directory...
#     Active transactions: 0
#     Active multiline: False
#     ✗ No match: General Error
#     ✗ No match: Application Update Process
#     ✗ No match: Application Launch Process
#     ✗ No match: Recording Session
#     ✗ No match: Cloudflare Token Generation
#     ✗ No match: Download Session Tracking
#     ✗ No match: File Encryption
#     ✗ No match: File Decryption
#     ✗ No match: Template Update Process
#     ✗ No match: Photo Processing Lifecycle
#     ✗ No match: Video Analyzer Lifecycle
#     ✗ No match: Camera Thread Lifecycle
#     ✗ No match: Video Clip Creation
#     ✗ No match: Full Video Concatenation Process
#     ✗ No match: Highlight Video Creation Process
#     ✗ No match: Concurrent Video Processing Lifecycle
#     ✗ No match: Socket.IO Client Connection Lifecycle
#     ✗ No match: Application Shutdown Process
#     → Created unmatched chunk
#
# --- Line 3: 2025-10-05 11:06:21 | INFO     | app.core.token_manager:ensure_token_directory:1...
#     Active transactions: 0
#     Active multiline: False
#     ✗ No match: General Error
#     ✗ No match: Application Update Process
#     ✗ No match: Application Launch Process
#     ✗ No match: Recording Session
#     ✗ No match: Cloudflare Token Generation
#     ✗ No match: Download Session Tracking
#     ✗ No match: File Encryption
#     ✗ No match: File Decryption
#     ✗ No match: Template Update Process
#     ✗ No match: Photo Processing Lifecycle
#     ✗ No match: Video Analyzer Lifecycle
#     ✗ No match: Camera Thread Lifecycle
#     ✗ No match: Video Clip Creation
#     ✗ No match: Full Video Concatenation Process
#     ✗ No match: Highlight Video Creation Process
#     ✗ No match: Concurrent Video Processing Lifecycle
#     ✗ No match: Socket.IO Client Connection Lifecycle
#     ✗ No match: Application Shutdown Process
#     → Created unmatched chunk
#
# --- Line 4: 2025-10-05 11:06:21 | INFO     | app.core.token_manager:ensure_token_directory:3...
#     Active transactions: 0
#     Active multiline: False
#     ✗ No match: General Error
#     ✗ No match: Application Update Process
#     ✗ No match: Application Launch Process
#     ✗ No match: Recording Session
#     ✗ No match: Cloudflare Token Generation
#     ✗ No match: Download Session Tracking
#     ✗ No match: File Encryption
#     ✗ No match: File Decryption
#     ✗ No match: Template Update Process
#     ✗ No match: Photo Processing Lifecycle
#     ✗ No match: Video Analyzer Lifecycle
#     ✗ No match: Camera Thread Lifecycle
#     ✗ No match: Video Clip Creation
#     ✗ No match: Full Video Concatenation Process
#     ✗ No match: Highlight Video Creation Process
#     ✗ No match: Concurrent Video Processing Lifecycle
#     ✗ No match: Socket.IO Client Connection Lifecycle
#     ✗ No match: Application Shutdown Process
#     → Created unmatched chunk
#
# --- Line 5: 2025-10-05 11:06:21 | INFO     | app.core.token_manager:load_tokens:46 - Loading...
#     Active transactions: 0
#     Active multiline: False
#     ✗ No match: General Error
#     ✗ No match: Application Update Process
#     ✗ No match: Application Launch Process
#     ✗ No match: Recording Session
#     ✗ No match: Cloudflare Token Generation
#     ✗ No match: Download Session Tracking
#     ✗ No match: File Encryption
#     ✗ No match: File Decryption
#     ✗ No match: Template Update Process
#     ✗ No match: Photo Processing Lifecycle
#     ✗ No match: Video Analyzer Lifecycle
#     ✗ No match: Camera Thread Lifecycle
#     ✗ No match: Video Clip Creation
#     ✗ No match: Full Video Concatenation Process
#     ✗ No match: Highlight Video Creation Process
#     ✗ No match: Concurrent Video Processing Lifecycle
#     ✗ No match: Socket.IO Client Connection Lifecycle
#     ✗ No match: Application Shutdown Process
#     → Created unmatched chunk
#
# --- Line 6: 2025-10-05 11:06:21 | INFO     | app.core.token_manager:load_tokens:74 - Loaded ...
#     Active transactions: 0
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7: 2025-10-05 11:06:25 | INFO     | app.core.configurations:apply_configs:203 - Suc...
#     Active transactions: 0
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 8: 2025-10-05 11:06:25 | DEBUG    | asyncio.proactor_events:__init__:634 - Using pr...
#     Active transactions: 0
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 9: 2025-10-05 11:06:25 | INFO     | app.main:lifespan:29 - Lifespan startup: launch...
#     Active transactions: 0
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 10: 2025-10-05 11:06:25 | INFO     | app.socketio.client:start:38 - Connecting to ht...
#     Active transactions: 0
#     Active multiline: False
#     ✓ Matched START: Socket.IO Client Connection Lifecycle (Transaction)
#
# --- Line 11: 2025-10-05 11:06:25 | INFO     | app.socketio.client:connect:17 - Connected!...
#     Active transactions: 1
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 12: 2025-10-05 14:07:55 | INFO     | app.core.configurations:ensure_config_directory...
#     Active transactions: 1
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 13: 2025-10-05 14:07:55 | INFO     | app.core.configurations:ensure_config_directory...
#     Active transactions: 1
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 14: 2025-10-05 14:07:55 | INFO     | app.core.token_manager:ensure_token_directory:1...
#     Active transactions: 1
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 15: 2025-10-05 14:07:55 | INFO     | app.core.token_manager:ensure_token_directory:3...
#     Active transactions: 1
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 16: 2025-10-05 14:07:55 | INFO     | app.core.token_manager:load_tokens:46 - Loading...
#     Active transactions: 1
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 17: 2025-10-05 14:07:55 | INFO     | app.core.token_manager:load_tokens:74 - Loaded ...
#     Active transactions: 1
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 18: 2025-10-05 14:07:58 | INFO     | app.core.configurations:apply_configs:203 - Suc...
#     Active transactions: 1
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 19: 2025-10-05 14:07:58 | DEBUG    | asyncio.proactor_events:__init__:634 - Using pr...
#     Active transactions: 1
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 20: 2025-10-05 14:07:58 | INFO     | app.main:lifespan:29 - Lifespan startup: launch...
#     Active transactions: 1
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 21: 2025-10-05 14:07:58 | INFO     | app.socketio.client:start:38 - Connecting to ht...
#     Active transactions: 1
#     Active multiline: False
#     ✓ Matched START: Socket.IO Client Connection Lifecycle (Transaction)
#
# --- Line 22: 2025-10-05 14:07:58 | INFO     | app.socketio.client:connect:17 - Connected!...
#     Active transactions: 1
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 23: 2025-10-05 14:47:03 | INFO     | app.api.recording:start_recording:32 - Starting...
#     Active transactions: 1
#     Active multiline: False
#     ✓ Matched START: Recording Session (Transaction)
#
# --- Line 24: 2025-10-05 14:47:04 | ERROR    | app.core.camera_manager:can_record:20 - Camera ...
#     Active transactions: 2
#     Active multiline: False
#     ✓ Matched START: General Error (Multi-line Error)
#
# --- Line 25: 2025-10-05 14:47:04 | ERROR    | app.core.camera_manager:can_record:20 - Camera ...
#     Active transactions: 2
#     Active multiline: True
#     ✓ Matched START: General Error (Multi-line Error)
#
# --- Line 26: 2025-10-05 14:47:05 | WARNING  | app.core.camera_manager:update_cam_config:96 - ...
#     Active transactions: 2
#     Active multiline: True
#     ✓ Closed multiline error (end pattern matched)
#     → Created unmatched chunk
#
# --- Line 27: 2025-10-05 14:47:07 | INFO     | app.core.camera_manager:update_cam_config:94 - ...
#     Active transactions: 2
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 28: 2025-10-05 14:47:07 | INFO     | app.core.camera_manager:update_cam_config:94 - ...
#     Active transactions: 2
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 29: 2025-10-05 14:47:07 | INFO     | app.core.session:init:39 - Session initialized ...
#     Active transactions: 2
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 30: 2025-10-05 14:47:07 | INFO     | app.core.session:_cleanup_video_directories:65 ...
#     Active transactions: 2
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 31: 2025-10-05 14:47:07 | WARNING  | app.core.analyzer_manager:_cleanup:39 - no vide...
#     Active transactions: 2
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 32: 2025-10-05 14:47:07 | WARNING  | app.core.analyzer_manager:_cleanup:46 - no phot...
#     Active transactions: 2
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 33: 2025-10-05 14:47:07 | INFO     | app.core.analyzer_manager:_start_photo_process:...
#     Active transactions: 2
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 34: 2025-10-05 14:47:07 | INFO     | app.core.session:_cleanup_video_directories:91 ...
#     Active transactions: 2
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 35: 2025-10-05 14:47:07 | INFO     | app.core.session:_cleanup_video_directories:91 ...
#     Active transactions: 2
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 36: 2025-10-05 14:47:07 | INFO     | app.core.analyzer_manager:_start_video_process:...
#     Active transactions: 2
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 37: 2025-10-05 14:47:07 | INFO     | app.core.recording:start:41 - Starting recordin...
#     Active transactions: 2
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 38: 2025-10-05 14:47:07 | INFO     | app.core.session:_cleanup_video_directories:91 ...
#     Active transactions: 2
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 39: 2025-10-05 14:47:07 | INFO     | app.core.session:_cleanup_video_directories:91 ...
#     Active transactions: 2
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 40: 2025-10-05 14:47:07 | INFO     | app.core.session:_cleanup_video_directories:91 ...
#     Active transactions: 2
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 41: 2025-10-05 14:47:07 | INFO     | app.core.analyzer.photo:run:48 - Photo Process ...
#     Active transactions: 2
#     Active multiline: False
#     ✓ Matched START: Photo Processing Lifecycle (Transaction)
#
# --- Line 42: 2025-10-05 14:47:07 | INFO     | app.core.session:_cleanup_video_directories:91 ...
#     Active transactions: 3
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 43: 2025-10-05 14:47:07 | INFO     | app.core.session:_cleanup_video_directories:91 ...
#     Active transactions: 3
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 44: 2025-10-05 14:47:07 | INFO     | app.core.session:_cleanup_video_directories:91 ...
#     Active transactions: 3
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 45: 2025-10-05 14:47:07 | INFO     | app.core.session:_cleanup_video_directories:91 ...
#     Active transactions: 3
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 46: 2025-10-05 14:47:07 | INFO     | app.core.session:_cleanup_video_directories:91 ...
#     Active transactions: 3
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 47: 2025-10-05 14:47:07 | INFO     | app.core.session:_cleanup_video_directories:91 ...
#     Active transactions: 3
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 48: 2025-10-05 14:47:07 | INFO     | app.core.session:_cleanup_video_directories:91 ...
#     Active transactions: 3
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 49: 2025-10-05 14:47:07 | INFO     | app.core.session:_cleanup_video_directories:91 ...
#     Active transactions: 3
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 50: 2025-10-05 14:47:07 | INFO     | app.core.session:_cleanup_video_directories:91 ...
#     Active transactions: 3
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 51: 2025-10-05 14:47:07 | INFO     | app.core.session:_cleanup_video_directories:91 ...
#     Active transactions: 3
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 52: 2025-10-05 14:47:07 | INFO     | app.core.session:_cleanup_video_directories:91 ...
#     Active transactions: 3
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 53: 2025-10-05 14:47:07 | INFO     | app.core.session:_cleanup_video_directories:91 ...
#     Active transactions: 3
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 54: 2025-10-05 14:47:07 | INFO     | app.core.session:_cleanup_video_directories:108...
#     Active transactions: 3
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 55: 2025-10-05 14:47:09 | DEBUG    | app.core.analyzer.human:__init__:18 - model loa...
#     Active transactions: 3
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 56: 2025-10-05 14:47:09 | DEBUG    | app.core.analyzer.video:run:22 - Analyzer proce...
#     Active transactions: 3
#     Active multiline: False
#     ✓ Matched START: Video Analyzer Lifecycle (Transaction)
#
# --- Line 57: 2025-10-05 14:47:11 | INFO     | app.core.recording:start:69 - Camera dimensions...
#     Active transactions: 4
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 58: 2025-10-05 14:47:14 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 4
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 59: 2025-10-05 14:47:14 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 4
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 60: 2025-10-05 14:47:15 | INFO     | app.core.recording:start:69 - Camera dimensions...
#     Active transactions: 4
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 61: 2025-10-05 14:47:15 | INFO     | app.api.recording:start_recording:36 - Recordin...
#     Active transactions: 4
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 62: 2025-10-05 14:47:15 | INFO     | app.core.download_tracker:record_session_start:...
#     Active transactions: 4
#     Active multiline: False
#     ✓ Matched START: Download Session Tracking (Transaction)
#
# --- Line 63: 2025-10-05 14:47:19 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 64: 2025-10-05 14:47:19 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 65: 2025-10-05 14:47:21 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 66: 2025-10-05 14:47:24 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 67: 2025-10-05 14:47:24 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 68: 2025-10-05 14:47:27 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 69: 2025-10-05 14:47:27 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 70: 2025-10-05 14:47:29 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 71: 2025-10-05 14:47:29 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 72: 2025-10-05 14:47:33 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 73: 2025-10-05 14:47:33 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 74: 2025-10-05 14:47:34 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 75: 2025-10-05 14:47:34 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 76: 2025-10-05 14:47:39 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 77: 2025-10-05 14:47:39 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 78: 2025-10-05 14:47:39 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 79: 2025-10-05 14:47:44 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 80: 2025-10-05 14:47:44 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 81: 2025-10-05 14:47:45 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 82: 2025-10-05 14:47:45 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 83: 2025-10-05 14:47:45 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 84: 2025-10-05 14:47:45 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 85: 2025-10-05 14:47:49 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 86: 2025-10-05 14:47:50 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 87: 2025-10-05 14:47:50 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 88: 2025-10-05 14:47:51 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 89: 2025-10-05 14:47:54 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 90: 2025-10-05 14:47:54 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 91: 2025-10-05 14:47:55 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 92: 2025-10-05 14:47:57 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 93: 2025-10-05 14:47:57 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 94: 2025-10-05 14:47:57 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 95: 2025-10-05 14:47:59 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 96: 2025-10-05 14:47:59 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 97: 2025-10-05 14:48:00 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 98: 2025-10-05 14:48:03 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 99: 2025-10-05 14:48:03 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 100: 2025-10-05 14:48:04 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 101: 2025-10-05 14:48:04 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 102: 2025-10-05 14:48:04 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 103: 2025-10-05 14:48:05 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 104: 2025-10-05 14:48:09 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 105: 2025-10-05 14:48:09 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 106: 2025-10-05 14:48:09 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 107: 2025-10-05 14:48:10 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 108: 2025-10-05 14:48:14 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 109: 2025-10-05 14:48:14 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 110: 2025-10-05 14:48:15 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 111: 2025-10-05 14:48:15 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 112: 2025-10-05 14:48:19 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 113: 2025-10-05 14:48:19 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 114: 2025-10-05 14:48:20 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 115: 2025-10-05 14:48:21 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 116: 2025-10-05 14:48:24 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 117: 2025-10-05 14:48:27 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 118: 2025-10-05 14:48:27 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 119: 2025-10-05 14:48:28 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 120: 2025-10-05 14:48:29 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 121: 2025-10-05 14:48:29 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 122: 2025-10-05 14:48:30 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 123: 2025-10-05 14:48:33 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 124: 2025-10-05 14:48:34 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 125: 2025-10-05 14:48:34 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 126: 2025-10-05 14:48:35 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 127: 2025-10-05 14:48:39 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 128: 2025-10-05 14:48:39 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 129: 2025-10-05 14:48:39 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 130: 2025-10-05 14:48:39 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 131: 2025-10-05 14:48:39 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 132: 2025-10-05 14:48:40 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 133: 2025-10-05 14:48:44 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 134: 2025-10-05 14:48:44 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 135: 2025-10-05 14:48:44 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 136: 2025-10-05 14:48:45 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 137: 2025-10-05 14:48:48 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 138: 2025-10-05 14:48:49 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 139: 2025-10-05 14:48:49 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 140: 2025-10-05 14:48:51 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 141: 2025-10-05 14:48:51 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 142: 2025-10-05 14:48:52 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 143: 2025-10-05 14:48:54 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 144: 2025-10-05 14:48:57 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 145: 2025-10-05 14:48:57 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 146: 2025-10-05 14:48:58 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 147: 2025-10-05 14:48:58 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 148: 2025-10-05 14:49:03 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 149: 2025-10-05 14:49:03 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 150: 2025-10-05 14:49:03 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 151: 2025-10-05 14:49:03 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 152: 2025-10-05 14:49:04 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 153: 2025-10-05 14:49:04 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 154: 2025-10-05 14:49:08 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 155: 2025-10-05 14:49:08 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 156: 2025-10-05 14:49:09 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 157: 2025-10-05 14:49:09 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 158: 2025-10-05 14:49:09 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 159: 2025-10-05 14:49:10 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 160: 2025-10-05 14:49:13 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 161: 2025-10-05 14:49:13 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 162: 2025-10-05 14:49:14 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 163: 2025-10-05 14:49:16 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 164: 2025-10-05 14:49:16 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 165: 2025-10-05 14:49:16 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 166: 2025-10-05 14:49:18 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 167: 2025-10-05 14:49:18 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 168: 2025-10-05 14:49:19 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 169: 2025-10-05 14:49:22 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 170: 2025-10-05 14:49:22 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 171: 2025-10-05 14:49:22 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 172: 2025-10-05 14:49:23 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 173: 2025-10-05 14:49:27 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 174: 2025-10-05 14:49:27 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 175: 2025-10-05 14:49:28 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 176: 2025-10-05 14:49:28 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 177: 2025-10-05 14:49:33 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 178: 2025-10-05 14:49:33 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 179: 2025-10-05 14:49:38 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 180: 2025-10-05 14:49:39 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 181: 2025-10-05 14:49:39 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 182: 2025-10-05 14:49:40 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 183: 2025-10-05 14:49:42 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 184: 2025-10-05 14:49:42 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 185: 2025-10-05 14:49:43 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 186: 2025-10-05 14:49:45 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 187: 2025-10-05 14:49:45 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 188: 2025-10-05 14:49:46 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 189: 2025-10-05 14:49:47 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 190: 2025-10-05 14:49:51 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 191: 2025-10-05 14:49:52 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 192: 2025-10-05 14:49:52 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 193: 2025-10-05 14:49:53 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 194: 2025-10-05 14:49:57 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 195: 2025-10-05 14:49:57 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 196: 2025-10-05 14:49:57 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 197: 2025-10-05 14:49:57 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 198: 2025-10-05 14:49:57 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 199: 2025-10-05 14:49:58 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 200: 2025-10-05 14:50:01 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 201: 2025-10-05 14:50:01 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 202: 2025-10-05 14:50:02 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 203: 2025-10-05 14:50:02 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 204: 2025-10-05 14:50:03 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 205: 2025-10-05 14:50:03 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 206: 2025-10-05 14:50:06 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 207: 2025-10-05 14:50:08 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 208: 2025-10-05 14:50:08 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 209: 2025-10-05 14:50:09 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 210: 2025-10-05 14:50:11 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 211: 2025-10-05 14:50:11 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 212: 2025-10-05 14:50:12 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 213: 2025-10-05 14:50:14 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 214: 2025-10-05 14:50:14 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 215: 2025-10-05 14:50:15 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 216: 2025-10-05 14:50:16 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 217: 2025-10-05 14:50:20 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 218: 2025-10-05 14:50:20 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 219: 2025-10-05 14:50:21 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 220: 2025-10-05 14:50:21 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 221: 2025-10-05 14:50:21 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 222: 2025-10-05 14:50:21 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 223: 2025-10-05 14:50:25 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 224: 2025-10-05 14:50:25 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 225: 2025-10-05 14:50:26 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 226: 2025-10-05 14:50:26 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 227: 2025-10-05 14:50:26 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 228: 2025-10-05 14:50:27 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 229: 2025-10-05 14:50:30 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 230: 2025-10-05 14:50:31 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 231: 2025-10-05 14:50:31 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 232: 2025-10-05 14:50:32 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 233: 2025-10-05 14:50:36 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 234: 2025-10-05 14:50:36 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 235: 2025-10-05 14:50:36 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 236: 2025-10-05 14:50:39 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 237: 2025-10-05 14:50:41 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 238: 2025-10-05 14:50:41 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 239: 2025-10-05 14:50:41 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# ...
#     Active transactions: 4
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7640: 2025-10-05 22:23:47 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 4
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7641: 2025-10-05 22:23:47 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 4
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7642: 2025-10-05 22:23:47 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 4
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7643: 2025-10-05 22:23:52 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 4
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7644: 2025-10-05 22:23:52 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 4
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7645: 2025-10-05 22:23:53 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 4
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7646: 2025-10-05 22:23:53 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 4
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7647: 2025-10-05 22:23:57 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 4
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7648: 2025-10-05 22:23:57 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 4
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7649: 2025-10-05 22:23:58 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 4
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7650: 2025-10-05 22:23:59 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 4
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7651: 2025-10-05 22:23:59 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 4
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7652: 2025-10-05 22:23:59 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 4
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7653: 2025-10-05 22:24:02 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 4
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7654: 2025-10-05 22:24:05 | INFO     | app.core.analyzer_manager:send_frame:30 - Addin...
#     Active transactions: 4
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7655: 2025-10-05 22:24:05 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 4
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7656: 2025-10-05 22:24:06 | INFO     | app.core.analyzer.frame_analyzer:add_to_heap:25...
#     Active transactions: 4
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7657: 2025-10-05 22:24:08 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 4
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7658: 2025-10-05 22:24:12 | INFO     | app.api.recording:stop_recording:62 - Stopping ...
#     Active transactions: 4
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7659: 2025-10-05 22:24:12 | INFO     | app.core.recording:stop:110 - Stopping recordin...
#     Active transactions: 4
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7660: 2025-10-05 22:24:12 | INFO     | app.core.recording:stop:116 - Stopping 2 cam th...
#     Active transactions: 4
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7661: 2025-10-05 22:24:12 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 4
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7662: 2025-10-05 22:24:12 | INFO     | app.core.recording:cam_thread:267 - Successfull...
#     Active transactions: 4
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7663: 2025-10-05 22:24:12 | INFO     | app.core.recording:cam_thread:287 - Camera 1 th...
#     Active transactions: 4
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7664: 2025-10-05 22:24:12 | INFO     | app.core.recording:cam_thread:287 - Camera 0 th...
#     Active transactions: 4
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7665: 2025-10-05 22:24:12 | INFO     | app.core.recording:stop:142 - All recordings st...
#     Active transactions: 4
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7666: 2025-10-05 22:24:13 | INFO     | app.core.analyzer_manager:stop:105 - Remove 36 ...
#     Active transactions: 4
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7667: 2025-10-05 22:24:13 | INFO     | app.core.analyzer_manager:_cleanup:35 - Stoppin...
#     Active transactions: 4
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7668: 2025-10-05 22:24:13 | INFO     | app.core.analyzer.video:run:40 - Analyzer proce...
#     Active transactions: 4
#     Active multiline: False
#     ✓ Matched END for transaction: Video Analyzer Lifecycle
#
# --- Line 7669: 2025-10-05 22:24:13 | INFO     | app.core.analyzer_manager:_cleanup:42 - Stoppin...
#     Active transactions: 3
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7670: 2025-10-05 22:24:13 | INFO     | app.core.analyzer.photo:run:58 - completing pho...
#     Active transactions: 3
#     Active multiline: False
#     ✓ Matched END for transaction: Photo Processing Lifecycle
#
# --- Line 7671: 2025-10-05 22:24:13 | INFO     | app.core.analyzer.photo_saver:_cleanup_and_get_...
#     Active transactions: 2
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7672: 2025-10-05 22:24:13 | ERROR    | app.core.analyzer.collage:create:16 - Not enoug...
#     Active transactions: 2
#     Active multiline: False
#     ✓ Matched START: General Error (Multi-line Error)
#
# --- Line 7673: 2025-10-05 22:24:13 | WARNING  | app.core.analyzer.photo_saver:finalize:119 - No...
#     Active transactions: 2
#     Active multiline: True
#     ✓ Closed multiline error (end pattern matched)
#     → Created unmatched chunk
#
# --- Line 7674: 2025-10-05 22:24:13 | INFO     | app.core.processing:_limit_cpu_usage:87 - CPU l...
#     Active transactions: 2
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7675: 2025-10-05 22:24:13 | INFO     | app.core.processing:process_all_videos:838 - St...
#     Active transactions: 2
#     Active multiline: False
#     ✓ Matched START: Concurrent Video Processing Lifecycle (Transaction)
#
# --- Line 7676: 2025-10-05 22:24:13 | INFO     | app.core.processing:create_full_concatenation_v...
#     Active transactions: 3
#     Active multiline: False
#     ✓ Matched START: Full Video Concatenation Process (Transaction)
#
# --- Line 7677: 2025-10-05 22:24:13 | INFO     | app.core.processing:create_highlight_video:591 ...
#     Active transactions: 4
#     Active multiline: False
#     ✓ Matched START: Highlight Video Creation Process (Transaction)
#
# --- Line 7678: 2025-10-05 22:24:13 | INFO     | app.core.processing:_discover_video_segments:12...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7679: 2025-10-05 22:24:13 | INFO     | app.core.processing:create_highlight_video:607 ...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7680: 2025-10-05 22:24:13 | INFO     | app.core.processing:_discover_video_segments:12...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7681: 2025-10-05 22:24:13 | INFO     | app.core.processing:create_highlight_video:627 ...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7682: 2025-10-05 22:24:13 | INFO     | app.core.processing:create_highlight_video:627 ...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7683: 2025-10-05 22:24:13 | INFO     | app.core.processing:create_highlight_video:627 ...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7684: 2025-10-05 22:24:13 | INFO     | app.core.processing:create_highlight_video:627 ...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7685: 2025-10-05 22:24:13 | INFO     | app.core.processing:create_highlight_video:627 ...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7686: 2025-10-05 22:24:13 | INFO     | app.core.processing:create_highlight_video:627 ...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7687: 2025-10-05 22:24:13 | INFO     | app.core.processing:create_highlight_video:632 ...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7688: 2025-10-05 22:24:13 | INFO     | app.core.processing:create_highlight_video:642 ...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7689: 2025-10-05 22:24:13 | INFO     | app.core.processing:create_highlight_video:667 ...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7690: 2025-10-05 22:24:13 | INFO     | app.core.processing:create_full_concatenation_v...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7691: 2025-10-05 22:24:13 | INFO     | app.core.processing:create_full_concatenation_v...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7692: 2025-10-05 22:24:13 | INFO     | app.core.processing:_concatenate_segments_with_...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7693: 2025-10-05 22:24:13 | INFO     | app.core.processing:_concatenate_segments_with_...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7694: 2025-10-05 22:24:13 | INFO     | app.core.processing:create_highlight_video:676 ...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7695: 2025-10-05 22:24:14 | INFO     | app.core.processing:create_highlight_video:711 ...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7696: 2025-10-05 22:24:14 | INFO     | app.core.processing:create_highlight_video:789 ...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7697: 2025-10-05 22:24:19 | INFO     | app.core.processing:_concatenate_segments_with_...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7698: 2025-10-05 22:24:19 | INFO     | app.core.processing:create_full_concatenation_v...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7699: 2025-10-05 22:24:19 | INFO     | app.core.processing:create_full_concatenation_v...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7700: 2025-10-05 22:24:19 | INFO     | app.core.processing:create_full_concatenation_v...
#     Active transactions: 5
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7701: 2025-10-05 22:24:19 | INFO     | app.core.processing:create_full_concatenation_v...
#     Active transactions: 5
#     Active multiline: False
#     ✓ Matched END for transaction: Full Video Concatenation Process
#
# --- Line 7702: 2025-10-05 22:24:19 | INFO     | app.core.processing:process_all_videos:863 - Fu...
#     Active transactions: 4
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7703: 2025-10-05 22:24:25 | INFO     | app.core.processing:create_highlight_video:809 ...
#     Active transactions: 4
#     Active multiline: False
#     ✓ Matched END for transaction: Highlight Video Creation Process
#
# --- Line 7704: 2025-10-05 22:24:25 | INFO     | app.core.processing:process_all_videos:866 - Hi...
#     Active transactions: 3
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7705: 2025-10-05 22:24:25 | INFO     | app.core.processing:process_all_videos:880 - Vi...
#     Active transactions: 3
#     Active multiline: False
#     ✓ Matched END for transaction: Concurrent Video Processing Lifecycle
#
# --- Line 7706: 2025-10-05 22:24:25 | INFO     | app.api.recording:stop_recording:65 - Recording...
#     Active transactions: 2
#     Active multiline: False
#     ✓ Matched END for transaction: Recording Session
#
# --- Line 7707: 2025-10-05 22:24:25 | INFO     | app.core.download_tracker:record_session_end:33...
#     Active transactions: 1
#     Active multiline: False
#     ✓ Matched END for transaction: Download Session Tracking
#
# --- Line 7708: 2025-10-05 22:25:48 | DEBUG    | app.api.download:get_download_url:31 - Creating...
#     Active transactions: 0
#     Active multiline: False
#     ✓ Matched START: Cloudflare Token Generation (Transaction)
#
# --- Line 7709: 2025-10-05 22:25:48 | INFO     | app.core.cloudflare_service:generate_token_with...
#     Active transactions: 1
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7710: 2025-10-05 22:25:48 | INFO     | app.core.token_manager:save_tokens:110 - Saved ...
#     Active transactions: 1
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7711: 2025-10-05 22:25:48 | INFO     | app.core.cloudflare_service:generate_token_with...
#     Active transactions: 1
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7712: 2025-10-05 22:25:48 | INFO     | app.core.cloudflare_service:generate_token_with...
#     Active transactions: 1
#     Active multiline: False
#     ✓ Matched END for transaction: Cloudflare Token Generation
#
# --- Line 7713: 2025-10-05 22:25:48 | INFO     | app.core.download_tracker:__log_event:11 - {"se...
#     Active transactions: 0
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7714: 2025-10-05 22:27:19 | INFO     | app.core.download_tracker:__log_event:11 - {"se...
#     Active transactions: 0
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7715: 2025-10-05 22:27:27 | INFO     | app.core.download_tracker:__log_event:11 - {"se...
#     Active transactions: 0
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7716: 2025-10-05 22:27:29 | INFO     | app.core.download_tracker:__log_event:11 - {"se...
#     Active transactions: 0
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7717: 2025-10-05 22:27:32 | INFO     | app.core.download_tracker:__log_event:11 - {"se...
#     Active transactions: 0
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7718: 2025-10-05 22:28:01 | INFO     | app.core.download_tracker:__log_event:11 - {"se...
#     Active transactions: 0
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7719: 2025-10-05 22:28:28 | INFO     | app.core.download_tracker:__log_event:11 - {"se...
#     Active transactions: 0
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7720: 2025-10-05 22:28:33 | INFO     | app.core.download_tracker:__log_event:11 - {"se...
#     Active transactions: 0
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7721: 2025-10-05 22:48:55 | INFO     | app.core.download_tracker:__log_event:11 - {"se...
#     Active transactions: 0
#     Active multiline: False
#     → Created unmatched chunk
#
# --- Line 7722: 2025-10-05 22:49:07 | INFO     | app.core.download_tracker:__log_event:11 - {"se...
#     Active transactions: 0
#     Active multiline: False
#     → Created unmatched chunk

# %%
len(chunks)
# Out:
# 7512

# %%
import re

# Your actual log line
test_line = "2025-10-05 11:06:21 | ERROR | app.core.configurations:ensure_config_directory:105 - Config directory ensured"

# Print first rule from your rules
rule = rules[0]  # Get first rule
print(f"Testing rule: {rule.rule_name}")
print(f"Start pattern: {rule.start_pattern}")
print(f"Test line: {test_line}\n")

# Test if it matches
pattern = re.compile(rule.start_pattern)
match = pattern.search(test_line)
print(f"Match result: {match}")

if not match:
    print("\n❌ Pattern doesn't match!")
    print("\nLet's check what your pattern expects vs what you have:")
    print(f"Pattern looks for: {rule.start_pattern[:100]}")
    print(f"Your log has: {test_line[:100]}")
# Out:
# Testing rule: General Multi-line Error
# Start pattern: ^(\d{4}-\d{2}-\d{2}\s+\d{2}:\d{2}:\d{2}\s+\|\s+(?:ERROR|CRITICAL|EXCEPTION|Traceback|WARNING|DEBUG)\s+\|\s+.*:\d+\s+-\s+.*)$
# Test line: 2025-10-05 11:06:21 | ERROR | app.core.configurations:ensure_config_directory:105 - Config directory ensured
#
# Match result: <re.Match object; span=(0, 108), match='2025-10-05 11:06:21 | ERROR | app.core.configurat>

# %%
# Show the first 5 rules and test them against a real log line
test_line = "2025-10-05 21:02:36 | INFO | app.core.analyzer_manager:send_frame:30 - Adding clip"

print("Testing patterns against:", test_line, "\n")

for i, rule in enumerate(rules):  # First 5 rules
    print(f"\n{'='*80}")
    print(f"Rule {i+1}: {rule.rule_name} ({rule.type})")
    print(f"Start pattern: {rule.start_pattern[:150]}...")
    
    # Test if it matches
    try:
        match = re.search(rule.start_pattern, test_line)
        if match:
            print(f"✓ MATCHES! Extracted: {match.groups()}")
        else:
            print(f"✗ No match")
    except Exception as e:
        print(f"✗ Error testing: {e}")
# Out:
# Testing patterns against: 2025-10-05 21:02:36 | INFO | app.core.analyzer_manager:send_frame:30 - Adding clip
#
#
# ================================================================================
# Rule 1: General Multi-line Error (Multi-line Error)
# Start pattern: ^(\d{4}-\d{2}-\d{2}\s+\d{2}:\d{2}:\d{2}\s+\|\s+(?:ERROR|CRITICAL|EXCEPTION|Traceback|WARNING|DEBUG)\s+\|\s+.*:\d+\s+-\s+.*)$...
# ✗ No match
#
# ================================================================================
# Rule 2: API Request Error (Multi-line Error)
# Start pattern: ^(\d{4}-\d{2}-\d{2}\s+\d{2}:\d{2}:\d{2}\s+\|\s+ERROR\s+\|\s+app\.api\..*:\d+\s+-\s+Error (?:opening|closing|detecting|in|while|uploading|serving|delet...
# ✗ No match
#
# ================================================================================
# Rule 3: Recording Session (Transaction)
# Start pattern: ^(\d{4}-\d{2}-\d{2}\s+\d{2}:\d{2}:\d{2}\s+\|\s+INFO\s+\|\s+app\.api\.recording:start_recording:\d+\s+-\s+Starting recording for game ([a-zA-Z0-9-]+)\s...
# ✗ No match
#
# ================================================================================
# Rule 4: Download URL Generation (Transaction)
# Start pattern: ^(\d{4}-\d{2}-\d{2}\s+\d{2}:\d{2}:\d{2}\s+\|\s+DEBUG\s+\|\s+app\.api\.download:get_download_url:\d+\s+-\s+Creating token for game_id:\s+([a-zA-Z0-9-]+...
# ✗ No match
#
# ================================================================================
# Rule 5: Camera API Control (Transaction)
# Start pattern: ^(\d{4}-\d{2}-\d{2}\s+\d{2}:\d{2}:\d{2}\s+\|\s+INFO\s+\|\s+app\.api\.cameras:open_cam:\d+\s+-\s+Camera\s+([0-9]+)\s+opened)$...
# ✗ No match
#
# ================================================================================
# Rule 6: Download Tracking Event (Transaction)
# Start pattern: ^(\d{4}-\d{2}-\d{2}\s+\d{2}:\d{2}:\d{2})\|\{"session_id"\s*:\s*"([a-zA-Z0-9-]+)".*$...
# ✗ No match

# %%
# Find the active transaction
print("\n\nActive Transactions:")
for chunk in chunks:
    if chunk.rule_type == "Transaction" and len(chunk.lines) > 1:
        print(f"\n{chunk.rule_name}:")
        print(f"  Lines: {len(chunk.lines)}")
        print(f"  Status: {chunk.status}")
        print(f"  First line: {chunk.lines[0][:100]}")
        if len(chunk.lines) > 1:
            print(f"  Last line: {chunk.lines[-1][:100]}")
        break
# Out:
# Active Transactions:
#
# Recording Session:
#   Lines: 2
#   Status: ChunkStatus.COMPLETE
#   First line: 2025-10-05 14:47:03 | INFO     | app.api.recording:start_recording:32 - Starting recording for game
#   Last line: 2025-10-05 14:52:54 | INFO     | app.api.recording:stop_recording:65 - Recording stopped successfull
